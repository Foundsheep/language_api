# %%
import requests
from bs4 import BeautifulSoup
url = "https://n.news.naver.com/mnews/article/001/0014653222?rc=N&ntype=RANKING"

r = requests.get(url=url)

soup = BeautifulSoup(r.content, 'html5lib')

# %%
news = soup.findAll('article', attrs={"id":"dic_area"})

# %%
len(news)
# Out:
# 1

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-useragent="python-requests/2.31.0" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="의료개혁특위 의사 몫 '빈칸'…&quot;참여해 전공의 처우 논의하길&quot;(종합)" property="og:title"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://n.news.naver.com/mnews/article/001/0014653222" property="og:url"/>
#   <meta content="https://imgnews.pstatic.net/image/001/2024/04/25/PYH2024042512070001300_P4_20240425164914889.jpg?type=w800" property="og:image"/>
#   <meta content="21명 민간위원 중 6명, 의사·병원단체에 배분…의협·대전협 등 '보이콧' &quot;전공의들, 직접 관련된 논의에 참여해 좋은 결과 나오게 해야&quot; 김병규 권지현 기자 = 의사단체들이 대통령 직속 의료개혁특별위원회(의료개혁특" property="og:description"/>
#   <meta content="연합뉴스 | 네이버" property="og:article:author"/>
#   <meta content="summary_large_image" name="twitter:card"/>
# ...
